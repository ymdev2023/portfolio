# %%
import scipy as sp
import pandas as pd
import numpy as np

from konlpy.tag import Kkma        ; kkma = Kkma()
from konlpy.tag import Hannanum    ; hannanum = Hannanum()
from konlpy.tag import Okt         ; t = Okt()     # 구 트위터
from konlpy.tag import *
import pickle

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %matplotlib inline
import os
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
from sklearn.tree import export_graphviz

import matplotlib.font_manager as fm
plt.rc('font', family='NanumGothic')

import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('mergedtitle.xlsx')
df
# Out:
#       Unnamed: 0      Date                                              title  \
# 0              0  20190101  Is it true that President Moon Jae-in's remark...
# 1              1  20190102  Samsung Display's investment expansion 'good n...
# 2              2  20190103  [Editorial] The KOSPI that collapsed in the 20...
# 3              3  20190104  "Gangnam-do 2 billion won is too expensive" Th...
# 4              4  20190105  [Photo] BLACKPINK Jisoo, 'Chic Eyes' (Golden D...
# ...          ...       ...                                                ...
# 1091        1091  20211227  61 million won Bitcoin, 25 million won in the ...
# 1092        1092  20211228  Ants sell Samsung Electronics 584 billion won,...
# 1093        1093  20211229  "60% of serious accidents happen in the constr...
# 1094        1094  20211230  Independent management of SK 'Intel NAND' "We ...
# 1095        1095  20211231  Lee Byung-ho, dean of Seoul National Universit...
#
#       Price
# 0         0
# 1         0
# 2         1
# 3         1
# 4         0
# ...     ...
# 1091      1
# 1092      0
# 1093      0
# 1094      0
# 1095      0
#
# [1096 rows x 4 columns]

# %%
import re

okt = Okt()
n_ = []
title_rename = []
for i in range(len(df)):
  if(i % 10000 ==0):
    print(i,"단계 완료")
  title_rename.append(re.sub("[\(\[].*?[\)\]]", "",df.iloc[i]['title']))
  n_.append(' '.join(okt.nouns(df.iloc[i]['title'])))
df['nouns'] = n_
df['title']=title_rename
df = df[df['nouns']!='']

#2차 불용어 제거
df['title'] = df['title'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
df['title'].replace('', np.nan, inplace=True)
df = df.dropna(how='any')
# Out:
# 0 단계 완료

# %%
vocab = {}
cnt = 0
for i in df['nouns']:
    i = i.split(' ')
    for j in range(len(i)):
        if i[j] in vocab or len(i[j])<=1:
            cnt=cnt+1
            pass
        else:
            vocab[i[j]]=0
vocab
print(len(vocab), vocab)
# Out:
# 21514 {'김현수': 0, '장관': 0, '탄소': 0, '중립': 0, '시대': 0, '농사': 0, '방식': 0, '세계': 0, '주방': 0, '밀폐': 0, '용기': 0, '대명사': 0, '이재': 0, '직접': 0, '일자리': 0, '채용': 0, '바이오': 0, '활황': 0, '모주': 0, '줄줄이': 0, '대기': 0, '유망': 0, '바이든': 0, '그린': 0, '친환경': 0, '신재생에너지': 0, '뉴욕증시': 0, '최고': 0, '마감': 0, '다우': 0, '천장': 0, '화이자': 0, '백신': 0, '긴급': 0, '사용': 0, '승인': 0, '한국': 0, '코로나': 0, '공급': 0, '개미': 0, '코스피': 0, '산타랠리': 0, '훌쩍': 0, '혼자': 0, '산다': 0, '소형': 0, '열풍': 0, '하남': 0, '시청역': 0, '해링턴': 0, '타워': 0, '센트럴': 0, '관심': 0, '모든': 0, '위기': 0, '기업': 0, '자영': 0, '업자': 0, '속보': 0, '연간': 0, '수출': 0, '지난해': 0, '선방': 0, '워낙': 0, '최악': 0, '전문직': 0, '주재': 0, '방문': 0, '교수': 0, '비자': 0, '개월': 0, '제한': 0, '단독': 0, '국민소득': 0, '백화점': 0, '직원': 0, '고객': 0, '화장실': 0, '일본차': 0, '점유': 0, '증발': 0, '닛산': 0, '인피니티': 0, '금융': 0, '감독': 0, '당국': 0, '수장': 0, '새해': 0, '화두': 0, '성수': 0, '정책금융': 0, '확대': 0, '액정': 0, '파손': 0, '최신': 0, '교체': 0, '고용노동부': 0, '테크': 0, '대리전': 0, '중국': 0, '전기차': 0, '스타트업': 0, '경쟁': 0, '재택근무': 0, '역설': 0, '작년': 0, '근로자': 0, '휴가': 0, '반도체': 0, '장비': 0, '홀딩': 0, '급등': 0, '지금': 0, '매수': 0, '포드': 0, '인도': 0, '마힌드라': 0, '합작': 0, '사업': 0, '전격': 0, '취소': 0, '여파': 0, '마켓': 0, '인사이트': 0, '계속': 0, '변수': 0, '국내': 0, '신평': 0, '사가': 0, '신축년': 0, '전망': 0, '유행': 0, '소상': 0, '공인': 0, '전통': 0, '시장': 0, '체감': 0, '경기': 0, '비트코인': 0, '조만간': 0, '조선': 0, '내화': 0, '업계': 0, '최초': 0, '품질': 0, '검사': 0, '도입': 0, '기부': 0, '성과': 0, '면화': 0, '가장': 0, '상승': 0, '랠리': 0, '설탕': 0, '커피': 0, '상승세': 0, '원자재': 0, '포커스': 0, '올해': 0, '환율': 0, '평균': 0, '충남': 0, '천안': 0, '자동차': 0, '부품': 0, '회사': 0, '관련': 0, '누적': 0, '진자': 0, '재팬': 0, '현재': 0, '진행형': 0, '유니클로': 0, '명동': 0, '최대': 0, '매장': 0, '은행': 0, '신용': 0, '대출': 0, '창구': 0, '소득': 0, '통신사': 0, '절차': 0, '돌입': 0, '거래': 0, '정지': 0, '월세': 0, '못내': 0, '임대료': 0, '분쟁': 0, '연속': 0, '훙광미': 0, '토종': 0, '브랜드': 0, '테슬라': 0, '증가': 0, '감소': 0, '마을': 0, '개인': 0, '포스트': 0, '준비': 0, '투자': 0, '전략': 0, '도서': 0, '인기': 0, '숙제': 0, '원전': 0, '재고': 0, '목소리': 0, '양주': 0, '분양': 0, '관리': 0, '지역': 0, '지정': 0, '매출': 0, '신기록': 0, '카카오': 0, '엔씨': 0, '부평': 0, '청천동': 0, '단지': 0, '대결': 0, '나이': 0, '집값': 0, '아이오': 0, '기아': 0, '기술': 0, '충전': 0, '차세대': 0, '임박': 0, '목동': 0, '델리': 0, '전세': 0, '매물': 0, '발사체': 0, '머스크': 0, '로켓': 0, '발사': 0, '성공': 0, '재개': 0, '숨통': 0, '우주': 0, '덕후': 0, '열정': 0, '민간': 0, '카운트다운': 0, '보험': 0, '비교': 0, '판매': 0, '업체': 0, '방카슈랑스': 0, '적용': 0, '논란': 0, '이성희': 0, '농협': 0, '중앙회': 0, '축산물': 0, '고사': 0, '유통': 0, '개혁': 0, '집중': 0, '미니': 0, '통신': 0, '대감': 0, '연성': 0, '롯데': 0, '케미칼': 0, '화학': 0, '실적': 0, '상향': 0, '말레이': 0, '정수기': 0, '코웨이': 0, '탈출': 0, '파업': 0, '체질개선': 0, '안정': 0, '수익': 0, '내자': 0, '아시아나': 0, '운항': 0, '이륙': 0, '시선': 0, '하량': 0, '헌법재판소': 0, '주가조작': 0, '징역형': 0, '벌금형': 0, '동시': 0, '선고': 0, '합헌': 0, '클릭': 0, '한경': 0, '피해': 0, '상공': 0, '지원': 0, '주식': 0, '핵심': 0, '가설': 0, '베팅': 0, '아이폰': 0, '출시': 0, '삼성': 0, '판매량': 0, '추월': 0, '전쟁': 0, '자녀': 0, '아토피': 0, '보장': 0, '확정': 0, '금액': 0, '평생': 0, '지급': 0, '보험사': 0, '상품': 0, '우보천리': 0, '마음': 0, '인사': 0, '포부': 0, '일반': 0, '렌즈': 0, '두께': 0, '카툭': 0, '해결': 0, '성능': 0, '쌍용차': 0, '지분매각': 0, '협의': 0, '막바지': 0, '다음주': 0, '시트': 0, '체결': 0, '부동산': 0, '언급': 0, '유시민': 0, '불로소득': 0, '과세': 0, '아스': 0, '우선': 0, '접종': 0, '아프리카': 0, '오늘': 0, '공식': 0, '출범': 0, '인구': 0, '사설': 0, '성장': 0, '효과': 0, '특파원': 0, '칼럼': 0, '현금': 0, '살포': 0, '회의론': 0, '현대차': 0, '역대': 0, '기록': 0, '신규': 0, '확진': 0, '신년': 0, '연휴': 0, '영향': 0, '항공사': 0, '팬데믹': 0, '손실': 0, '악몽': 0, '매각': 0, '마무리': 0, '단계': 0, '승자': 0, '부호': 0, '재산': 0, '증시': 0, '셀트리온': 0, '청년': 0, '서정진': 0, '혈액': 0, '만수': 0, '박사': 0, '수혜': 0, '국가': 0, '미래': 0, '노트': 0, '희망': 0, '본격': 0, '신한은행': 0, '배달': 0, '음식': 0, '주문': 0, '토스': 0, '뱅크': 0, '영업': 0, '시작': 0, '달러': 0, '돌파': 0, '사상': 0, '경신': 0, '당선': 0, '활짝': 0, '청정': 0, '에너지': 0, '편입': 0, '종목': 0, '식약처': 0, '전담': 0, '구성': 0, '품목': 0, '허가': 0, '이내': 0, '수술': 0, '사람': 0, '가입': 0, '집사': 0, '전자': 0, '황정수': 0, '이슈': 0, '보기': 0, '서울': 0, '유명': 0, '중식': 0, '하림각': 0, '중단': 0, '운영': 0, '적자': 0, '급성': 0, '클린': 0, '장기': 0, '분산': 0, '자율': 0, '항해': 0, '선박' ...

# %%
df['주가변동'].value_counts()
# Out:
# 1.0    32186
# 0.0    29724
# Name: 주가변동, dtype: int64

# %%
up = 32186
down = 29724
up_ratio = up/(up+down)
down_ratio = down/(up+down)

import collections
for i,w in enumerate(df['nouns']):
    w = w.split(' ')
    if (df.iloc[i]['주가변동']==1):
        for j in range(len(w)):
            noun = w[j]
            if len(noun)<=1:
              continue
            vocab[noun] = vocab[noun] + down_ratio
    else:
        for j in range(len(w)):
            noun = w[j]
            if len(noun)<=1:
              continue
            vocab[noun] = vocab[noun] - up_ratio

# %%
sent_dictionary = vocab

# %%
len(sent_dictionary.keys())
# Out:
# 21514

# %%
total = []
for i,w  in enumerate(df['nouns']):
    sent_score = 0
    w= w.split(' ')
    for j in w:
        if(len(j)<=1):
          continue
        elif(j not in sent_dictionary):
          continue
        else:
          sent_score = sent_score + sent_dictionary[j]
    total.append(sent_score/len(w))
df['sent_score'] = total

# %%
df
# Out:
#              일자                              제목  주가변동  \
# 0      20210101    김현수 장관 탄소중립 시대 농사 방식 완전히 바꿔야   1.0
# 1      20210101  잠그고 또 잠근다 세계의 주방 꽉 잡은 밀폐용기 대명사   1.0
# 2      20210101      이재갑 장관 직접일자리 만개 중  분기 내 채용   1.0
# 3      20210101       바이오팜 활황 맞은 공모주 대어급 줄줄이 대기   1.0
# 4      20210101    바이든 시대 그린가 뜬다 친환경 신재생에너지 담아라   1.0
# ...         ...                             ...   ...
# 61906  20211231                 허위 재무제표로 억 부당이익   0.0
# 61907  20211231    새만금 태양광 주민참여채권 억 발행 연  수익 설계   0.0
# 61908  20211231          중앙디앤엠 자회사 에코엠넷 흡수합병 완료   0.0
# 61909  20211231  현대오일뱅크 폐플라스틱 열분해유 넣어 친환경 납사 생산   0.0
# 61910  20211231          글로벌 정글 헤쳐나갈 호랑이 기업 키우자   0.0
#
#                              nouns  sent_score
# 0            김현수 장관 탄소 중립 시대 농사 방식    3.169721
# 1              또 세계 주방 꽉 밀폐 용기 대명사    2.440617
# 2            이재 갑 장관 직접 일자리 중 내 채용    2.607895
# 3          바이오 활황 모주 급 줄줄이 대기 유망 주   -7.588528
# 4        바이든 시대 그린 친환경 신재생에너지 유망 주    1.940536
# ...                            ...         ...
# 61906                허위 재무제표 부당 이익   -5.886044
# 61907  새만금 태양광 주민 참여 채권 발행 연 수익 설계    1.722368
# 61908    중앙 디앤엠 자회사 에코 엠넷 흡수 합병 완료    0.215801
# 61909    뱅크 폐 플라스틱 열분해 유 친환경 납사 생산    1.949786
# 61910                글로벌 정글 호랑이 기업   18.359990
#
# [61910 rows x 5 columns]

# %%
sum = 0
for i in range(len(vocab)):
  sum = sum + list(vocab.values())[i]
sent_mean = sum/len(vocab)

a_ = []
for i in range(len(df)):
  if(df.iloc[i]['sent_score']>sent_mean):
    a_.append(1)
  else:
    a_.append(0)
df['sent_label'] = a_

# %%
df['일자'].value_counts()
# Out:
# 20210908    411
# 20210128    328
# 20210428    325
# 20210420    293
# 20210427    293
#            ...
# 20211016     14
# 20210102     14
# 20211030     13
# 20210320     11
# 20210123      8
# Name: 일자, Length: 365, dtype: int64

# %%
df1 = df['일자'].value_counts()

# %%
df1 = df1.sort_index()
df1
# Out:
# 20210101     75
# 20210102     14
# 20210103     93
# 20210104    270
# 20210105    261
#            ...
# 20211227    193
# 20211228    190
# 20211229    181
# 20211230    191
# 20211231    110
# Name: 일자, Length: 365, dtype: int64

# %%
df1 = pd.DataFrame(df1)

# df2 = df1.rename(columns={'일자': '횟수'})
df1.reset_index(inplace=True)
# df2.rename(index='일자')
# # df2 = df2.rename(columns={'index': '일자'})

# %%
df1
# Out:
#         index   일자
# 0    20210101   75
# 1    20210102   14
# 2    20210103   93
# 3    20210104  270
# 4    20210105  261
# ..        ...  ...
# 360  20211227  193
# 361  20211228  190
# 362  20211229  181
# 363  20211230  191
# 364  20211231  110
#
# [365 rows x 2 columns]

# %%
df1.columns = ['일자', '횟수']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18132/2959875156.py in <module>
# ----> 1 df1.columns = ['일자', '횟수']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 2 elements

# %%
df1.set_index('일자')
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18132/2740585510.py in <module>
# ----> 1 df1.set_index('일자')
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['일자'] are in the columns"

# %%
df.to_pickle('sent_data.pkl')

# %%
df.to_csv('sent_score_whole.csv', index=True, encoding='utf-8')
df
# Out:
#              일자                              제목  주가변동  \
# 0      20210101    김현수 장관 탄소중립 시대 농사 방식 완전히 바꿔야   1.0
# 1      20210101  잠그고 또 잠근다 세계의 주방 꽉 잡은 밀폐용기 대명사   1.0
# 2      20210101      이재갑 장관 직접일자리 만개 중  분기 내 채용   1.0
# 3      20210101       바이오팜 활황 맞은 공모주 대어급 줄줄이 대기   1.0
# 4      20210101    바이든 시대 그린가 뜬다 친환경 신재생에너지 담아라   1.0
# ...         ...                             ...   ...
# 61906  20211231                 허위 재무제표로 억 부당이익   0.0
# 61907  20211231    새만금 태양광 주민참여채권 억 발행 연  수익 설계   0.0
# 61908  20211231          중앙디앤엠 자회사 에코엠넷 흡수합병 완료   0.0
# 61909  20211231  현대오일뱅크 폐플라스틱 열분해유 넣어 친환경 납사 생산   0.0
# 61910  20211231          글로벌 정글 헤쳐나갈 호랑이 기업 키우자   0.0
#
#                              nouns  sent_score  sent_label
# 0            김현수 장관 탄소 중립 시대 농사 방식    3.169721           1
# 1              또 세계 주방 꽉 밀폐 용기 대명사    2.440617           1
# 2            이재 갑 장관 직접 일자리 중 내 채용    2.607895           1
# 3          바이오 활황 모주 급 줄줄이 대기 유망 주   -7.588528           0
# 4        바이든 시대 그린 친환경 신재생에너지 유망 주    1.940536           1
# ...                            ...         ...         ...
# 61906                허위 재무제표 부당 이익   -5.886044           0
# 61907  새만금 태양광 주민 참여 채권 발행 연 수익 설계    1.722368           1
# 61908    중앙 디앤엠 자회사 에코 엠넷 흡수 합병 완료    0.215801           1
# 61909    뱅크 폐 플라스틱 열분해 유 친환경 납사 생산    1.949786           1
# 61910                글로벌 정글 호랑이 기업   18.359990           1
#
# [61910 rows x 6 columns]

# %%
df.to_excel('sent_score_whole.xlsx', index=True, encoding='utf-8')
df
# Out:
#              일자                              제목  주가변동  \
# 0      20210101    김현수 장관 탄소중립 시대 농사 방식 완전히 바꿔야   1.0
# 1      20210101  잠그고 또 잠근다 세계의 주방 꽉 잡은 밀폐용기 대명사   1.0
# 2      20210101      이재갑 장관 직접일자리 만개 중  분기 내 채용   1.0
# 3      20210101       바이오팜 활황 맞은 공모주 대어급 줄줄이 대기   1.0
# 4      20210101    바이든 시대 그린가 뜬다 친환경 신재생에너지 담아라   1.0
# ...         ...                             ...   ...
# 61906  20211231                 허위 재무제표로 억 부당이익   0.0
# 61907  20211231    새만금 태양광 주민참여채권 억 발행 연  수익 설계   0.0
# 61908  20211231          중앙디앤엠 자회사 에코엠넷 흡수합병 완료   0.0
# 61909  20211231  현대오일뱅크 폐플라스틱 열분해유 넣어 친환경 납사 생산   0.0
# 61910  20211231          글로벌 정글 헤쳐나갈 호랑이 기업 키우자   0.0
#
#                              nouns  sent_score  sent_label
# 0            김현수 장관 탄소 중립 시대 농사 방식    3.169721           1
# 1              또 세계 주방 꽉 밀폐 용기 대명사    2.440617           1
# 2            이재 갑 장관 직접 일자리 중 내 채용    2.607895           1
# 3          바이오 활황 모주 급 줄줄이 대기 유망 주   -7.588528           0
# 4        바이든 시대 그린 친환경 신재생에너지 유망 주    1.940536           1
# ...                            ...         ...         ...
# 61906                허위 재무제표 부당 이익   -5.886044           0
# 61907  새만금 태양광 주민 참여 채권 발행 연 수익 설계    1.722368           1
# 61908    중앙 디앤엠 자회사 에코 엠넷 흡수 합병 완료    0.215801           1
# 61909    뱅크 폐 플라스틱 열분해 유 친환경 납사 생산    1.949786           1
# 61910                글로벌 정글 호랑이 기업   18.359990           1
#
# [61910 rows x 6 columns]

# %%
df1 = df.groupby(['일자']).sum()

# %%
df1
# Out:
#            주가변동  sent_score  sent_label
# 일자
# 20210101   75.0  230.606418          57
# 20210102   14.0   27.511624          11
# 20210103   93.0  243.469208          71
# 20210104  270.0  125.028069         175
# 20210105    0.0 -327.444465         124
# ...         ...         ...         ...
# 20211227  193.0  -33.983774         113
# 20211228    0.0 -182.494010          96
# 20211229    0.0 -268.612711          77
# 20211230    0.0 -235.003238          92
# 20211231    0.0   -4.206881          64
#
# [365 rows x 3 columns]

# %%
df_new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18132/1519603319.py in <module>
# ----> 1 df_new
#
# NameError: name 'df_new' is not defined

# %%
# df2.set_index('일자')

df1['mean_sent_score']= df1['sent_score'] / df1['횟수']
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '횟수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18132/312300775.py in <module>
#       1 # df2.set_index('일자')
#       2
# ----> 3 df1['mean_sent_score']= df1['sent_score'] / df1['횟수']
#       4 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '횟수'

# %%
label_mean = df_new['mean_sent_score'].mean()

# %%
a_ = []
for i in range(365):
  if(df_new.iloc[i]['mean_sent_score']>label_mean):
    a_.append(1)
  else:
    a_.append(0)
df_new['sent_label_whole'] = a_

# %%
df_new
# Out:
#              일자                              제목  주가변동_x  \
# 0      20210101    김현수 장관 탄소중립 시대 농사 방식 완전히 바꿔야     1.0
# 1      20210101  잠그고 또 잠근다 세계의 주방 꽉 잡은 밀폐용기 대명사     1.0
# 2      20210101      이재갑 장관 직접일자리 만개 중  분기 내 채용     1.0
# 3      20210101       바이오팜 활황 맞은 공모주 대어급 줄줄이 대기     1.0
# 4      20210101    바이든 시대 그린가 뜬다 친환경 신재생에너지 담아라     1.0
# ...         ...                             ...     ...
# 61905  20211231                 허위 재무제표로 억 부당이익     0.0
# 61906  20211231    새만금 태양광 주민참여채권 억 발행 연  수익 설계     0.0
# 61907  20211231          중앙디앤엠 자회사 에코엠넷 흡수합병 완료     0.0
# 61908  20211231  현대오일뱅크 폐플라스틱 열분해유 넣어 친환경 납사 생산     0.0
# 61909  20211231          글로벌 정글 헤쳐나갈 호랑이 기업 키우자     0.0
#
#                              nouns  sent_score_x  sent_label_x  주가변동_y  \
# 0            김현수 장관 탄소 중립 시대 농사 방식      3.169721             1    75.0
# 1              또 세계 주방 꽉 밀폐 용기 대명사      2.440617             1    75.0
# 2            이재 갑 장관 직접 일자리 중 내 채용      2.607895             1    75.0
# 3          바이오 활황 모주 급 줄줄이 대기 유망 주     -7.588528             0    75.0
# 4        바이든 시대 그린 친환경 신재생에너지 유망 주      1.940536             1    75.0
# ...                            ...           ...           ...     ...
# 61905                허위 재무제표 부당 이익     -5.886044             0     0.0
# 61906  새만금 태양광 주민 참여 채권 발행 연 수익 설계      1.722368             1     0.0
# 61907    중앙 디앤엠 자회사 에코 엠넷 흡수 합병 완료      0.215801             1     0.0
# 61908    뱅크 폐 플라스틱 열분해 유 친환경 납사 생산      1.949786             1     0.0
# 61909                글로벌 정글 호랑이 기업     18.359990             1     0.0
#
#        sent_score_y  sent_label_y
# 0        230.606418            57
# 1        230.606418            57
# 2        230.606418            57
# 3        230.606418            57
# 4        230.606418            57
# ...             ...           ...
# 61905     -4.206881            64
# 61906     -4.206881            64
# 61907     -4.206881            64
# 61908     -4.206881            64
# 61909     -4.206881            64
#
# [61910 rows x 9 columns]

# %%
df1

# %%
df_new = pd.merge(df,df1,how='outer', on='일자')

# %%
df

# %%
df_new.to_csv('sent_score_new.csv', index=True, encoding='euc-kr')

# %%
df['sent_label_whole'].value_counts()

# %%
df = pd.read_csv('KOSPInews-en.csv')
df
# Out:
#          Date                                              title  \
# 0    20210101  [Book Village] Corporate personal "Let's prepa...
# 1    20210102  Suspension of Harimgak, a famous Chinese resta...
# 2    20210103  Only 9 out of 20 companies that have reduced g...
# 3    20210104  Bernanke, "The US economy recovers faster than...
# 4    20210105  The government releases 180,000 tons of stockp...
# ..        ...                                                ...
# 360  20211227  61 million won Bitcoin, 25 million won in the ...
# 361  20211228  Ants sell Samsung Electronics 584 billion won,...
# 362  20211229  "60% of serious accidents happen in the constr...
# 363  20211230  Independent management of SK 'Intel NAND' "We ...
# 364  20211231  Lee Byung-ho, dean of Seoul National Universit...
#
#      stock price fluctuations
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           0
# ..                        ...
# 360                         1
# 361                         0
# 362                         0
# 363                         0
# 364                         0
#
# [365 rows x 3 columns]

# %%
df1 = pd.read_csv('sent_score_new.csv', encoding="euc-kr")
df1
# Out:
#      Unnamed: 0        일자  KOSPI  sent_score  sent_label  뉴스개수  \
# 0             0  20210101     75  230.606418          57    75
# 1             1  20210102     14   27.511624          11    14
# 2             2  20210103     93  243.469208          71    93
# 3             3  20210104    270  125.028069         175   270
# 4             4  20210105      0 -327.444465         124   261
# ..          ...       ...    ...         ...         ...   ...
# 360         360  20211227    193  -33.983774         113   193
# 361         361  20211228      0 -182.494010          96   190
# 362         362  20211229      0 -268.612711          77   181
# 363         363  20211230      0 -235.003238          92   191
# 364         364  20211231      0   -4.206881          64   110
#
#      mean_sent_score  sent_label_whole
# 0           3.074752                 1
# 1           1.965116                 1
# 2           2.617948                 1
# 3           0.463067                 1
# 4          -1.254576                 0
# ..               ...               ...
# 360        -0.176082                 1
# 361        -0.960495                 0
# 362        -1.484048                 0
# 363        -1.230383                 0
# 364        -0.038244                 1
#
# [365 rows x 8 columns]

# %%
df
# Out:
#          Date                                              title  \
# 0    20210101  [Book Village] Corporate personal "Let's prepa...
# 1    20210102  Suspension of Harimgak, a famous Chinese resta...
# 2    20210103  Only 9 out of 20 companies that have reduced g...
# 3    20210104  Bernanke, "The US economy recovers faster than...
# 4    20210105  The government releases 180,000 tons of stockp...
# ..        ...                                                ...
# 360  20211227  61 million won Bitcoin, 25 million won in the ...
# 361  20211228  Ants sell Samsung Electronics 584 billion won,...
# 362  20211229  "60% of serious accidents happen in the constr...
# 363  20211230  Independent management of SK 'Intel NAND' "We ...
# 364  20211231  Lee Byung-ho, dean of Seoul National Universit...
#
#      stock price fluctuations
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           0
# ..                        ...
# 360                         1
# 361                         0
# 362                         0
# 363                         0
# 364                         0
#
# [365 rows x 3 columns]

# %%
df['sent_score']=df1['sent_label_whole']

# %%
df
# Out:
#          Date                                              title  \
# 0    20210101  [Book Village] Corporate personal "Let's prepa...
# 1    20210102  Suspension of Harimgak, a famous Chinese resta...
# 2    20210103  Only 9 out of 20 companies that have reduced g...
# 3    20210104  Bernanke, "The US economy recovers faster than...
# 4    20210105  The government releases 180,000 tons of stockp...
# ..        ...                                                ...
# 360  20211227  61 million won Bitcoin, 25 million won in the ...
# 361  20211228  Ants sell Samsung Electronics 584 billion won,...
# 362  20211229  "60% of serious accidents happen in the constr...
# 363  20211230  Independent management of SK 'Intel NAND' "We ...
# 364  20211231  Lee Byung-ho, dean of Seoul National Universit...
#
#      stock price fluctuations  sent_score
# 0                           1           1
# 1                           1           1
# 2                           1           1
# 3                           1           1
# 4                           0           0
# ..                        ...         ...
# 360                         1           1
# 361                         0           0
# 362                         0           0
# 363                         0           0
# 364                         0           1
#
# [365 rows x 4 columns]

# %%
df.to_csv('sent_score_new_en.csv', index=True, encoding='utf-8')
