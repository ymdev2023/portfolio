# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-형태소-분석" data-toc-modified-id="1.-형태소-분석-1">1. 형태소 분석</a></span></li><li><span><a href="#2.-감성분석-모델-만들기" data-toc-modified-id="2.-감성분석-모델-만들기-2">2. 감성분석 모델 만들기</a></span></li></ul></div>

# %%
import scipy as sp
import pandas as pd
import numpy as np

from konlpy.tag import Kkma        ; kkma = Kkma()
from konlpy.tag import Hannanum    ; hannanum = Hannanum()
from konlpy.tag import Okt         ; t = Okt()     # 구 트위터
from konlpy.tag import *
import pickle

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %matplotlib inline
import os
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
from sklearn.tree import export_graphviz

import matplotlib.font_manager as fm
plt.rc('font', family='NanumGothic')

import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

import warnings
warnings.filterwarnings('ignore')

# %%
# 팍스넷 + 네이버 뉴스데이터 연결하기

news_df = pd.read_csv('팍스넷&네이버_뉴스타이틀.csv')
print(news_df.shape)
news_df
# Out:
# (4800, 3)
#       Unnamed: 0                          뉴스제목  주가변동
# 0              0                    52주 신고가 종목     0
# 1              1   증시요약(9) - 기술적 분석 특징주 A(코스닥)     0
# 2              2  증시요약(10) - 기술적 분석 특징주 B(코스닥)     0
# 3              3         오후장 기술적 분석 특징주 A(코스닥)     0
# 4              4         오후장 기술적 분석 특징주 B(코스닥)     0
# ...          ...                           ...   ...
# 4795        2235                    신용비율 상위 종목     1
# 4796        2236                     뉴욕증시 마감시황     1
# 4797        2237               코스피 하락률 상위 50종목     1
# 4798        2238                 미국 주요 ETF 등락률     1
# 4799        2239   외국인/기관 연속 순매도일 상위 20종목(코스피)     1
#
# [4800 rows x 3 columns]

# %%
title_list = news_df.뉴스제목.values.tolist()

# %%
print(len(title_list))
title_list
# Out:
# 4800
# ['52주 신고가 종목',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '전일자 증권사 투자의견(유지/신규)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스닥 상승률 상위 50종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 하락률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스피 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '신용비율 상위 종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '코스피 상승률 상위 50종목',
#  '52주 신고가 종목',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스피 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스닥 기관 순매수,도 상위20종목',
#  '주말의 이슈&테마 스케줄',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스닥 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '신용비율 상위 종목',
#  '코스피 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '장중 주요 종목 공시',
#  '코스피 기관 순매수,도 상위20종목',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '52주 신고가 종목',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '신용비율 상위 종목',
#  '미 연준, QE 테이퍼링 공론화 \'후퇴\' 양상...전문가들 "실수, 성급했다"',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스피 하락률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 기관 순매수,도 상위20종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스닥 상승률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스피 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '전일자 증권사 투자의견(유지/신규)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '52주 신고가 종목',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스피 기관 순매수,도 상위20종목',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스닥 기관 순매수,도 상위20종목',
#  '코스피 외국인 순매수,도 상위20종목',
#  '코스닥 하락률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '15일 장 마감 후 주요 종목 뉴스',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국계 순매수,도 상위종목(코스피) 금액기준',
#  '코스닥 하락률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '신용비율 상위 종목',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '주말의 이슈&테마 스케줄',
#  '코스피 하락률 상위 50종목',
#  '52주 신고가 종목',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '[재송]21일 장 마감 후 주요 종목뉴스',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '장마감 후 주요 종목 공시',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '신용비율 상위 종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 하락률 상위 50종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스피 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스피 상승률 상위 50종목',
#  '코스피 외국인 순매수,도 상위20종목',
#  '[금일 중국증시 포인트(1.21)]전기차 랠리 재개, 희토류 영구자석 테마주 부상',
#  '코스피 하락률 상위 50종목',
#  '[재송]20일 장 마감 후 주요 종목뉴스',
#  '코스피 하락률 상위 50종목',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '52주 신고가 종목',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '26일 장 마감 후 주요 종목 뉴스',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '장중 주요 종목 공시',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  "코스피 역대최고…'거품' 논란에도 목표가 상향 톱5 종목은",
#  '신용비율 상위 종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '장마감 후 주요 종목 공시',
#  '현대차,LG화학부터 네이버까지…주도주 실적시즌 본격 개막',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '"달아오른 증시 온도, 27일에 달렸다"',
#  '하루에도 코스피 80포인트씩 출렁…변동성 경계령',
#  '전일자 증권사 투자의견(유지/신규)',
#  '코스피 하락률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스닥 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '증시요약(5) - 특징 종목(코스닥)',
#  '코스닥 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '공매도 누른 美 `게임스탑`…韓 공매도잔고 1위는 `셀트리온`',
#  '장중 주요 종목 공시',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '29일 장 마감 후 주요 종목 뉴스',
#  '코스닥 하락률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '장마감 후 주요 종목 공시',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오늘의 이슈&테마 스케줄',
#  '코스피 하락률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '[재송]28일 장 마감 후 주요 종목 뉴스',
#  '코스피 기관 순매수,도 상위20종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '코스닥 기관 순매수,도 상위20종목',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스닥 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '[분석] 너무 달린 코스피, 3000선 붕괴 \'조정 불가피\'…"추세 반전은 아냐"',
#  '코스피 외국인 순매수,도 상위20종목',
#  '신용비율 상위 종목',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '장중 주요 종목 공시',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '1일 장 마감 후 주요 종목 뉴스',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '신용비율 상위 종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  "세계증시 랠리...'레딧 군단' 진격에 실버 관련 자산 급등",
#  '코스닥 상승률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '증권사 신규추천 종목',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스피 기관 순매수,도 상위20종목',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  "차량용 반도체 품귀현상…관련株도 '들썩들썩'",
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '장중 주요 종목 공시',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '장마감 후 주요 종목 공시',
#  '52주 신고가 종목',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '신용비율 상위 종목',
#  '3일 장 마감 후 주요 종목 뉴스',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스닥 상승률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '전일자 증권사 투자의견(유지/신규)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 기관 순매수,도 상위20종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '주요 기업 4분기 실적 발표 일정(2021.02.03 기준, 연결기준)',
#  '코스피 상승률 상위 50종목',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '장중 주요 종목 공시',
#  '52주 신고가 종목',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스닥 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  "'아직 안 오른 주식 있을까'…관심 쏠리는 저평가株",
#  '코스피 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '“땡큐, 쿠팡” 수혜주 상한가 직행',
#  '코스피 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '전일자 증권사 투자의견(유지/신규)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스피 하락률 상위 50종목',
#  '증시요약(5) - 특징 종목(코스닥)',
#  '신용비율 상위 종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '15일 장 마감 후 주요 종목 뉴스',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스닥 상승률 상위 50종목',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '장마감 후 주요 종목 공시',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '52주 신고가 종목',
#  '결산시즌...코스닥 적자기업 비상',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '장중 주요 종목 공시',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '코로나 타격…결산시즌 코스닥 관리종목 속출하나',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '신용비율 상위 종목',
#  '전일자 증권사 투자의견(유지/신규)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스피 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 기관 순매수,도 상위20종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스피 상승률 상위 50종목',
#  '中 알리바바가 뉴욕 찍고 홍콩증시 간 이유',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '52주 신고가 종목',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '17일 장 마감 후 주요 종목 뉴스',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 하락률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스피 하락률 상위 50종목',
#  '증시요약(5) - 특징 종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '코스피 상승률 상위 50종목',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '코스닥 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '신용비율 상위 종목',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스피 하락률 상위 50종목',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  'KB ETF, 수수료 업계 최저.. 10일간 856억원',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '[재송]17일 장 마감 후 주요 종목 뉴스',
#  '18일 장 마감 후 주요 종목 뉴스',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '52주 신고가 종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스피 하락률 상위 50종목',
#  '신용비율 상위 종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '장중 주요 종목 공시',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스피 상승률 상위 50종목',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '22일 장마감 후 주요 종목 뉴스',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '장중 주요 종목 공시',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '52주 신고가 종목',
#  '"커머스 재평가 신바람" 티몬 관련株 들썩',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '[e공시 눈에 띄네] 코스닥-19일',
#  '코스피 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '신용비율 상위 종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 상승률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '코스닥 상승률 상위 50종목',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '[재송]22일 장마감 후 주요 종목뉴스',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '장마감 후 주요 종목 공시',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '장중 주요 종목 공시',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '[자금조달]정대선·이휴원 주주 고려자산개발, 삼성동 개발사업 1750억 PF',
#  '코스닥 상승률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '신용비율 상위 종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '전일자 증권사 투자의견(유지/신규)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스피 하락률 상위 50종목',
#  '골드만삭스 "코스피 3700 간다…공매도 재개 영향 크지 않을 것"',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '코스피 상승률 상위 50종목',
#  '[e공시 눈에 띄네]코스닥-22일',
#  '코스닥 기관 순매수,도 상위20종목',
#  '장마감 후 주요 종목 공시',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '[재송]24일 장 마감 후 주요 종목뉴스',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '장중 주요 종목 공시',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '전일자 증권사 투자의견(유지/신규)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스피 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스피) 금액기준',
#  '증시요약(5) - 특징 종목(코스닥)',
#  '신용거래 급증 삼성전자·셀트리온헬스·씨젠·기아차 순',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '코스닥 상승률 상위 50종목',
#  '신용비율 상위 종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '신용거래 급증, 삼성전자·셀트리온헬스·컴투스·기아차',
#  '코스피 상승률 상위 50종목',
#  '25일 장 마감 후 주요 종목뉴스',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '장마감 후 주요 종목 공시',
#  '장중 주요 종목 공시',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '코스닥 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '코스피 하락률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스피 상승률 상위 50종목',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스피 기관 순매수,도 상위20종목',
#  '신용비율 상위 종목',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '(재송)25일 장 마감 후 주요 종목뉴스',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '26일 장 마감 후 주요 종목 뉴스',
#  '코스닥 상승률 상위 50종목',
#  '코스피 외국인 순매수,도 상위20종목',
#  '코스닥 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스피) 금액기준',
#  '증시요약(5) - 특징 종목(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '[재송]2일 장 마감 후 주요 종목뉴스',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '신용비율 상위 종목',
#  '코스피 하락률 상위 50종목',
#  '3일 장 마감 후 주요 종목뉴스',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스닥 상승률 상위 50종목',
#  '롤러코스터 ‘가덕도 테마주’ …수혜 여부는?',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '[특징주]수소차 사업 기대감…에스퓨어셀·에스에너지 등 관련주 강세',
#  '코스피 외국인 순매수,도 상위20종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '코스닥 상승률 상위 50종목',
#  '[뉴욕증시] 기술주 밸류에이션 부담에 하락…나스닥 1.69%↓',
#  '코스피 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '5일 장 마감 후 주요 종목 뉴스',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '[속보]파월 "연준 목표 위협하는 금융시장의 무질서 우려"',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '장마감 후 주요 종목 공시',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스피 하락률 상위 50종목',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '[재송]4일 장 마감 후 주요 종목뉴스',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스피 외국인 순매수,도 상위20종목',
#  '연준 금리 통제력 상실? 월가가 원하는 두 가지 해법',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스피 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '신용비율 상위 종목',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스피 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스닥 하락률 상위 50종목',
#  '장중 주요 종목 공시',
#  '코스닥 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스피 상승률 상위 50종목',
#  '[속보] 파월 "참을성" 발언에 뉴욕증시 하락 반전',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '"인플레 걱정하지 마"…시장 달래기 나선 옐런',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  "연일 매도에 들끓는 여론…국민연금 '투자허용범위' 손볼 듯",
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '9일 장 마감후 주요종목 뉴스',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '"美 국채투매 끝나간다" 뉴욕증시 일제 상승',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '전일자 증권사 투자의견(유지/신규)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  "인플레이션 논란에 강한 업종은 '통신'…물가 상승시 '로우볼'·하락시 '배당주'",
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '장중 주요 종목 공시',
#  '신용비율 상위 종목',
#  '코스피 기관 순매수,도 상위20종목',
#  '증시요약(5) - 특징 종목(코스닥)',
#  '코스닥 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '테슬라 급락 배터리 주식 된서리…"악재만 있는 건 아니다"',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '장마감 후 주요 종목 공시',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '장중 주요 종목 공시',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '[뉴욕증시]10년물 국채 탠트럼 없었지만…빅테크주는 또 내렸다',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  "美증시 국채 '암초' 피했다…다우 1.5%↑",
#  '코스닥 하락률 상위 50종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '코스피 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '증시요약(5) - 특징 종목(코스닥)',
#  '개인들, 2차전지株 충전 중',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '신용비율 상위 종목',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '한풀꺾인 증시, 언제 살아날까…美 FOMC 주목',
#  '코스피 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  "[포토] 쿠팡, 뉴욕증시에 '로켓 상장'…시총 72조로 치솟아",
#  '11일 장 마감후 주요종목 뉴스',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '장중 주요 종목 공시',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '연기금 51일째 순매도...경기민감株만 담았다',
#  '코스닥 상승률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  "'로블록스'發 훈풍…국내 메타버스 관련주 찾기 분주",
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스피 하락률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '신용비율 상위 종목',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '코스피 상승률 상위 50종목',
#  '코스피 외국인 순매수,도 상위20종목',
#  '코스피 기관 순매수,도 상위20종목',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '세계증시, FOMC 앞두고 경제회복 기대에 상승',
#  '코스피 하락률 상위 50종목',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '16일 장 마감 이후 주요 종목뉴스',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '장마감 후 주요 종목 공시',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '전일자 증권사 투자의견(유지/신규)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스닥 하락률 상위 50종목',
#  '코스닥 기관 순매수,도 상위20종목',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '연기금 돌아왔나…넉달 만의 연속 순매수에 코스피 3060 안착',
#  '코스피 상승률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '장중 주요 종목 공시',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '코스닥 하락률 상위 50종목',
#  '코스피 외국인 순매수,도 상위20종목',
#  '신용비율 상위 종목',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '코스피 하락률 상위 50종목',
#  '코스닥 상승률 상위 50종목',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '1분기부터 기대 이상…깜짝 실적 기대株는?',
#  '52주 신고가 종목',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '코스피 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '증시요약(4) - 특징 종목(코스피)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '코스피 하락률 상위 50종목',
#  '장마감 후 주요 종목 공시',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '신용비율 상위 종목',
#  '52주 신고가 종목',
#  '증시요약(6) - 특징 상한가 및 급등종목',
#  '코스피 상승률 상위 50종목',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '코스피 하락률 상위 50종목',
#  '세계증시 소폭 상승...연준이 달랜 국채금리 불안감 도로 제자리',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  '코스닥 하락률 상위 50종목',
#  '코스피 기관 순매수,도 상위20종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스피)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '코스피 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스피 하락률 상위 50종목',
#  '코스피 외국인 순매수,도 상위20종목',
#  '코스닥 상승률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  "'쿠팡 샀다, 팔았다' 불안한 서학개미…뉴욕증시 간 한국기업도 '답답'",
#  '18일 장 마감 후 주요 종목 뉴스',
#  '코스피 하락률 상위 50종목',
#  '증시요약(9) - 기술적 분석 특징주 A(코스닥)',
#  '증시요약(10) - 기술적 분석 특징주 B(코스닥)',
#  '증시요약(7) - 기술적 분석 특징주 A(코스피)',
#  '오후장 기술적 분석 특징주 A(코스닥)',
#  '52주 신고가 종목',
#  '증시요약(8) - 기술적 분석 특징주 B(코스피)',
#  '19일 장 마감 후 주요 종목 뉴스',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오후장 기술적 분석 특징주 B(코스닥)',
#  '오후장 기술적 분석 특징주 A(코스피)',
#  '오전장 기술적 분석 특징주 A(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '코스닥 하락률 상위 50종목',
#  '장마감 후 주요 종목 공시',
#  '외국인/기관 연속 순매수일 상위 20종목(코스닥)',
#  '코스피 기관 순매수,도 상위20종목',
#  '코스닥 하락률 상위 50종목',
#  '오후장 기술적 분석 특징주 B(코스피)',
#  '오전장 기술적 분석 특징주 A(코스피)',
#  '코스피 하락률 상위 50종목',
#  '외국인/기관 연속 순매도일 상위 20종목(코스닥)',
#  '코스닥 상승률 상위 50종목',
#  '코스피 상승률 상위 50종목',
#  '코스피 외국인 순매수,도 상위20종목',
#  '코스닥 하락률 상위 50종목',
#  '오전장 기술적 분석 특징주 B(코스닥)',
#  '오전장 기술적 분석 특징주 B(코스피)',
#  '외국계 순매수,도 상위종목(코스피) 수량기준',
#  "'따상상' 물건너 간 SK바이오사이언스, 지금 사도 될까",
#  '코스닥 기관 순매수,도 상위20종목',
#  '외국계 순매수,도 상위종목(코스닥) 수량기준',
#  '미래에셋 오류 진화…“접속 시도 시점 기준 보상”(종합)',
#  '외국인/기관 연속 순매수일 상위 20종목(코스피)',
#  '코스닥 외국인 순매수,도 상위20종목',
#  '종가 동시호가 특이 종목(코스피/코스닥)',
#  '외국계 순매수,도 상위종목(코스피) 금액기준',
#  '코스닥 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스피) 금액기준',
#  '코스피 하락률 상위 50종목',
#  '외국계 순매수,도 상위종목(코스닥) 금액기준',
#  ...]

# %%
title_text = ''

for each_line in title_list:
    title_text = title_text + each_line + '\n'
    
title_text
# Out:
# '52주 신고가 종목\n증시요약(9) - 기술적 분석 특징주 A(코스닥)\n증시요약(10) - 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 A(코스닥)\n오후장 기술적 분석 특징주 B(코스닥)\n증시요약(8) - 기술적 분석 특징주 B(코스피)\n오전장 기술적 분석 특징주 A(코스닥)\n증시요약(7) - 기술적 분석 특징주 A(코스피)\n오전장 기술적 분석 특징주 B(코스닥)\n오전장 기술적 분석 특징주 A(코스닥)\n오후장 기술적 분석 특징주 B(코스피)\n외국인/기관 연속 순매수일 상위 20종목(코스닥)\n오전장 기술적 분석 특징주 B(코스피)\n전일자 증권사 투자의견(유지/신규)\n오전장 기술적 분석 특징주 B(코스닥)\n외국인/기관 연속 순매도일 상위 20종목(코스닥)\n오후장 기술적 분석 특징주 A(코스피)\n코스피 하락률 상위 50종목\n외국계 순매수,도 상위종목(코스닥) 수량기준\n코스닥 하락률 상위 50종목\n코스닥 하락률 상위 50종목\n코스닥 상승률 상위 50종목\n코스닥 하락률 상위 50종목\n코스피 하락률 상위 50종목\n오전장 기술적 분석 특징주 B(코스피)\n코스닥 상승률 상위 50종목\n증시요약(6) - 특징 상한가 및 급등종목\n외국계 순매수,도 상위종목(코스닥) 수량기준\n코스닥 하락률 상위 50종목\n외국인/기관 연속 순매수일 상위 20종목(코스피)\n코스피 상승률 상위 50종목\n오전장 기술적 분석 특징주 A(코스피)\n외국인/기관 연속 순매도일 상위 20종목(코스피)\n코스닥 외국인 순매수,도 상위20종목\n외국계 순매수,도 상위종목(코스닥) 금액기준\n신용비율 상위 종목\n오전장 기술적 분석 특징주 A(코스피)\n코스피 하락률 상위 50종목\n코스닥 기관 순매수,도 상위20종목\n코스피 상승률 상위 50종목\n52주 신고가 종목\n증시요약(9) - 기술적 분석 특징주 A(코스닥)\n증시요약(7) - 기술적 분석 특징주 A(코스피)\n증시요약(10) - 기술적 분석 특징주 B(코스닥)\n증시요약(8) - 기술적 분석 특징주 B(코스피)\n오후장 기술적 분석 특징주 A(코스닥)\n오전장 기술적 분석 특징주 A(코스닥)\n오후장 기술적 분석 특징주 B(코스닥)\n오전장 기술적 분석 특징주 A(코스닥)\n오전장 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 B(코스피)\n오후장 기술적 분석 특징주 A(코스피)\n오전장 기술적 분석 특징주 A(코스피)\n오전장 기술적 분석 특징주 B(코스피)\n오전장 기술적 분석 특징주 B(코스닥)\n코스닥 하락률 상위 50종목\n오전장 기술적 분석 특징주 A(코스피)\n코스피 하락률 상위 50종목\n코스피 상승률 상위 50종목\n코스닥 상승률 상위 50종목\n외국인/기관 연속 순매수일 상위 20종목(코스닥)\n코스닥 하락률 상위 50종목\n외국계 순매수,도 상위종목(코스닥) 수량기준\n코스피 하락률 상위 50종목\n오전장 기술적 분석 특징주 B(코스피)\n외국인/기관 연속 순매도일 상위 20종목(코스닥)\n외국인/기관 연속 순매도일 상위 20종목(코스피)\n외국인/기관 연속 순매수일 상위 20종목(코스피)\n코스닥 기관 순매수,도 상위20종목\n주말의 이슈&테마 스케줄\n외국계 순매수,도 상위종목(코스닥) 금액기준\n증시요약(6) - 특징 상한가 및 급등종목\n코스닥 상승률 상위 50종목\n외국계 순매수,도 상위종목(코스닥) 수량기준\n코스닥 외국인 순매수,도 상위20종목\n신용비율 상위 종목\n코스피 상승률 상위 50종목\n코스닥 하락률 상위 50종목\n장중 주요 종목 공시\n코스피 기관 순매수,도 상위20종목\n증시요약(9) - 기술적 분석 특징주 A(코스닥)\n증시요약(10) - 기술적 분석 특징주 B(코스닥)\n증시요약(7) - 기술적 분석 특징주 A(코스피)\n오후장 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 A(코스닥)\n증시요약(8) - 기술적 분석 특징주 B(코스피)\n52주 신고가 종목\n오전장 기술적 분석 특징주 B(코스닥)\n오전장 기술적 분석 특징주 A(코스닥)\n오후장 기술적 분석 특징주 A(코스피)\n오전장 기술적 분석 특징주 A(코스닥)\n오후장 기술적 분석 특징주 B(코스피)\n오전장 기술적 분석 특징주 B(코스닥)\n오전장 기술적 분석 특징주 A(코스피)\n코스닥 하락률 상위 50종목\n코스피 하락률 상위 50종목\n코스닥 상승률 상위 50종목\n신용비율 상위 종목\n미 연준, QE 테이퍼링 공론화 \'후퇴\' 양상...전문가들 "실수, 성급했다"\n코스닥 하락률 상위 50종목\n오전장 기술적 분석 특징주 A(코스피)\n코스닥 하락률 상위 50종목\n오전장 기술적 분석 특징주 B(코스피)\n코스피 하락률 상위 50종목\n외국인/기관 연속 순매수일 상위 20종목(코스닥)\n코스닥 기관 순매수,도 상위20종목\n외국인/기관 연속 순매도일 상위 20종목(코스닥)\n외국인/기관 연속 순매도일 상위 20종목(코스피)\n외국계 순매수,도 상위종목(코스닥) 수량기준\n코스닥 하락률 상위 50종목\n외국계 순매수,도 상위종목(코스피) 수량기준\n코스닥 외국인 순매수,도 상위20종목\n증시요약(6) - 특징 상한가 및 급등종목\n코스닥 상승률 상위 50종목\n외국인/기관 연속 순매수일 상위 20종목(코스피)\n오전장 기술적 분석 특징주 B(코스피)\n코스피 하락률 상위 50종목\n코스피 기관 순매수,도 상위20종목\n외국계 순매수,도 상위종목(코스닥) 금액기준\n전일자 증권사 투자의견(유지/신규)\n증시요약(9) - 기술적 분석 특징주 A(코스닥)\n증시요약(10) - 기술적 분석 특징주 B(코스닥)\n증시요약(8) - 기술적 분석 특징주 B(코스피)\n오후장 기술적 분석 특징주 B(코스닥)\n증시요약(7) - 기술적 분석 특징주 A(코스피)\n오전장 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 A(코스닥)\n오전장 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 B(코스피)\n오후장 기술적 분석 특징주 A(코스피)\n오전장 기술적 분석 특징주 A(코스닥)\n52주 신고가 종목\n코스닥 하락률 상위 50종목\n오전장 기술적 분석 특징주 B(코스피)\n오전장 기술적 분석 특징주 B(코스피)\n코스피 기관 순매수,도 상위20종목\n코스닥 상승률 상위 50종목\n오전장 기술적 분석 특징주 A(코스닥)\n오전장 기술적 분석 특징주 A(코스피)\n코스닥 기관 순매수,도 상위20종목\n코스피 외국인 순매수,도 상위20종목\n코스닥 하락률 상위 50종목\n코스피 상승률 상위 50종목\n외국인/기관 연속 순매수일 상위 20종목(코스닥)\n15일 장 마감 후 주요 종목 뉴스\n코스닥 외국인 순매수,도 상위20종목\n코스피 하락률 상위 50종목\n외국계 순매수,도 상위종목(코스닥) 수량기준\n외국계 순매수,도 상위종목(코스피) 금액기준\n코스닥 하락률 상위 50종목\n외국인/기관 연속 순매도일 상위 20종목(코스닥)\n코스피 하락률 상위 50종목\n외국인/기관 연속 순매수일 상위 20종목(코스피)\n외국계 순매수,도 상위종목(코스닥) 금액기준\n오전장 기술적 분석 특징주 A(코스피)\n신용비율 상위 종목\n종가 동시호가 특이 종목(코스피/코스닥)\n증시요약(6) - 특징 상한가 및 급등종목\n주말의 이슈&테마 스케줄\n코스피 하락률 상위 50종목\n52주 신고가 종목\n증시요약(9) - 기술적 분석 특징주 A(코스닥)\n증시요약(10) - 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 A(코스닥)\n증시요약(7) - 기술적 분석 특징주 A(코스피)\n오전장 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 B(코스닥)\n증시요약(8) - 기술적 분석 특징주 B(코스피)\n오전장 기술적 분석 특징주 A(코스닥)\n오전장 기술적 분석 특징주 A(코스닥)\n외국인/기관 연속 순매수일 상위 20종목(코스닥)\n[재송]21일 장 마감 후 주요 종목뉴스\n오전장 기술적 분석 특징주 B(코스닥)\n오후장 기술적 분석 특징주 B(코스피)\n오전장 기술적 분석 특징주 B(코스피)\n장마감 후 주요 종목 공시\n외국인/기관 연속 순매도일 상위 20종목(코스닥)\n오후장 기술적 분석 ...

# %% [markdown]
# # 1. 형태소 분석

# %%
tokens_ko = t.morphs(title_text)

# %%
tokens_ko
# Out:
# ['52',
#  '주',
#  '신고',
#  '가',
#  '종목',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '9',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '10',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '8',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '7',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '수일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '전',
#  '일자',
#  '증권사',
#  '투자',
#  '의견',
#  '(',
#  '유지',
#  '/',
#  '신규',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '도일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '코스피',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '외국',
#  '계',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '수량',
#  '기준',
#  '\n',
#  '코스닥',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스닥',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스닥',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스닥',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스피',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '코스닥',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '6',
#  ')',
#  '-',
#  '특징',
#  '상한',
#  '가',
#  '및',
#  '급등',
#  '종목',
#  '\n',
#  '외국',
#  '계',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '수량',
#  '기준',
#  '\n',
#  '코스닥',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '수일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '코스피',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '도일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '코스닥',
#  '외국인',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '20',
#  '종목',
#  '\n',
#  '외국',
#  '계',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '금액',
#  '기준',
#  '\n',
#  '신용',
#  '비율',
#  '상위',
#  '종목',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '코스피',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스닥',
#  '기관',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '20',
#  '종목',
#  '\n',
#  '코스피',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '52',
#  '주',
#  '신고',
#  '가',
#  '종목',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '9',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '7',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '10',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '8',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '코스닥',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '코스피',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스피',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스닥',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '수일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '코스닥',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '외국',
#  '계',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '수량',
#  '기준',
#  '\n',
#  '코스피',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '도일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '도일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '외국인',
#  '/',
#  '기관',
#  '연속',
#  '순',
#  '매',
#  '수일',
#  '상위',
#  '20',
#  '종목',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '코스닥',
#  '기관',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '20',
#  '종목',
#  '\n',
#  '주말',
#  '의',
#  '이슈',
#  '&',
#  '테마',
#  '스케줄',
#  '\n',
#  '외국',
#  '계',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '금액',
#  '기준',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '6',
#  ')',
#  '-',
#  '특징',
#  '상한',
#  '가',
#  '및',
#  '급등',
#  '종목',
#  '\n',
#  '코스닥',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '외국',
#  '계',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '종목',
#  '(',
#  '코스닥',
#  ')',
#  '수량',
#  '기준',
#  '\n',
#  '코스닥',
#  '외국인',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '20',
#  '종목',
#  '\n',
#  '신용',
#  '비율',
#  '상위',
#  '종목',
#  '\n',
#  '코스피',
#  '상',
#  '승률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '코스닥',
#  '하락',
#  '률',
#  '상위',
#  '50',
#  '종목',
#  '\n',
#  '장',
#  '중',
#  '주요',
#  '종목',
#  '공시',
#  '\n',
#  '코스피',
#  '기관',
#  '순',
#  '매수',
#  ',',
#  '도',
#  '상위',
#  '20',
#  '종목',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '9',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '10',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '7',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '증시',
#  '요약',
#  '(',
#  '8',
#  ')',
#  '-',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스피',
#  ')',
#  '\n',
#  '52',
#  '주',
#  '신고',
#  '가',
#  '종목',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'B',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오전',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  '(',
#  '코스닥',
#  ')',
#  '\n',
#  '오후',
#  '장',
#  '기술',
#  '적',
#  '분석',
#  '특징',
#  '주',
#  'A',
#  ...]

# %%
import nltk
ko = nltk.Text(tokens_ko)
ko
# Out:
# <Text: 52 주 신고 가 종목
#  증시 요약...>

# %%
print(len(ko.tokens))          # 토큰 전체 개수
print(len(set(ko.tokens)))     # 토큰 unique 개수
# Out:
# 53725
# 1753

# %%
# 빈도수가 높은 단어 출력

ko.vocab().most_common(200)
# Out:
# [('\n', 4800),
#  ('(', 3178),
#  (')', 3177),
#  ('종목', 2554),
#  ('코스닥', 2229),
#  ('상위', 2033),
#  ('주', 1930),
#  ('특징', 1900),
#  ('기술', 1765),
#  ('적', 1763),
#  ('분석', 1758),
#  ('코스피', 1609),
#  ('장', 1457),
#  ('50', 1017),
#  ('순', 923),
#  ('B', 899),
#  ('A', 857),
#  ('오전', 805),
#  ('하락', 724),
#  ('률', 703),
#  (',', 674),
#  ('증시', 643),
#  ('20', 622),
#  ('-', 593),
#  ('요약', 584),
#  ('매수', 548),
#  ('도', 547),
#  ('외국인', 504),
#  ('기관', 494),
#  ('오후', 472),
#  ('/', 462),
#  ('매', 375),
#  ('연속', 374),
#  ('상', 340),
#  ('승률', 334),
#  ('기준', 331),
#  ('주요', 306),
#  ('계', 300),
#  ('외국', 299),
#  ('수량', 252),
#  ('후', 209),
#  ('가', 200),
#  ('도일', 198),
#  ('공시', 175),
#  ('수일', 173),
#  ("'", 163),
#  ('…', 158),
#  ('[', 151),
#  ('마감', 145),
#  (']', 144),
#  ('9', 121),
#  ('10', 121),
#  ('8', 121),
#  ('7', 120),
#  ('뉴스', 111),
#  ('신고', 98),
#  ('비율', 98),
#  ('감', 98),
#  ('52', 97),
#  ('장마', 97),
#  ('신용', 96),
#  ('및', 90),
#  ('"', 90),
#  ('급등', 86),
#  ('상한', 84),
#  ('투자', 83),
#  ('6', 83),
#  ('전', 78),
#  ('일자', 76),
#  ('에', 76),
#  ('증권사', 69),
#  ('신규', 69),
#  ('·', 68),
#  ('의견', 65),
#  ('유지', 61),
#  ('중', 60),
#  ('株', 59),
#  ('뉴욕증시', 48),
#  ('금액', 47),
#  ('실적', 46),
#  ('의', 36),
#  ('은', 35),
#  ('재송', 34),
#  ('美', 33),
#  ('관련', 30),
#  ('강세', 30),
#  ('종가', 29),
#  ('동시', 29),
#  ('호가', 29),
#  ('특이', 29),
#  ('기', 29),
#  ('5', 27),
#  ('테마', 26),
#  ('기업', 26),
#  ('는', 24),
#  ('?', 24),
#  ('시', 24),
#  ('로', 24),
#  ('공매도', 23),
#  ('상승', 23),
#  ('&', 21),
#  ('...', 21),
#  ('황', 21),
#  ('세계', 19),
#  ('나스닥', 19),
#  ('금리', 19),
#  ('SK', 19),
#  ('이슈', 18),
#  ('재개', 18),
#  ('오늘', 18),
#  ('발표', 18),
#  ('일정', 18),
#  ("'…", 18),
#  ('이', 18),
#  ('↑', 18),
#  ('미국', 18),
#  ('스케줄', 17),
#  ('연', 17),
#  ('준', 16),
#  ('‘', 16),
#  ('다우', 16),
#  ('개미', 16),
#  ('지', 16),
#  ('분', 16),
#  ('`', 15),
#  ('1분', 15),
#  ('변동', 15),
#  ('.', 14),
#  ('연결', 14),
#  ('삼성', 14),
#  ('’', 14),
#  ('테마주', 13),
#  ('최고', 13),
#  ('↓', 13),
#  ('시장', 13),
#  ('일제', 13),
#  ('주목', 13),
#  ('기대', 13),
#  ('+', 13),
#  ('주가', 13),
#  ('자산', 12),
#  ('“', 12),
#  ('”', 12),
#  ('배당', 12),
#  ('직전', 12),
#  ('30분', 12),
#  ('히', 12),
#  ('바이든', 12),
#  ('혼', 12),
#  ('사상', 12),
#  ('돌파', 12),
#  ('에도', 11),
#  ('전자', 11),
#  ('등', 11),
#  ('우려', 11),
#  ('"…', 11),
#  ('2', 11),
#  ('상장', 11),
#  ('앞두고', 11),
#  ('ETF', 10),
#  ('국내', 10),
#  ('백신', 10),
#  ('영업', 10),
#  ('이익', 10),
#  ('예', 10),
#  ('상치', 10),
#  ('2021년', 10),
#  ("…'", 9),
#  ('1', 9),
#  ('선', 9),
#  ('반도체', 9),
#  ('주식', 9),
#  ('평가', 9),
#  ('코로나', 9),
#  ('재', 9),
#  ('매도', 9),
#  ('국채', 9),
#  ('소', 9),
#  ('바이오', 9),
#  ('윤석열', 9),
#  ('으로', 9),
#  ('3', 9),
#  ('조', 9),
#  ('등락', 9),
#  ('속', 9),
#  ('FOMC', 8),
#  ('폭', 8),
#  ('한국', 8),
#  ('지수', 8),
#  ('엔', 8),
#  ('200', 8),
#  ('전망', 8),
#  ('거래', 8),
#  ('100', 8),
#  ('들', 7),
#  ('목표', 7),
#  ('저', 7),
#  ('18일', 7),
#  ('22일', 7),
#  ('눈', 7)]

# %%
# 불용어(stopwords) 제거하기

stop_words = ['\n',"'",'…',',','[',']','(',')','"','주','에','코스닥','특징','종목','·','장','코스피','증시','-','적',\
              '도','기술','분석','마감','‘','`','요약','가','’','의','이','오전','★','은','“','대','”','한','B','로',\
              '?','3','선','A','오후','는','5','!','"…','상','들','1','만에','제','2','…"','20','일','서','명',"'…",'기',\
              '···','10','소','등','으로','자','전','률','미','...','50','세','시','안','폭',"…'",'만','9','VI','까지',\
              '눈','더','e','량','고','인','52','성','띄네','1%','부터','다','감','을','지','4','에도','수','7','것','째',\
             '체크','기','···','중','계','관련','왜','1억원','총','내','과','젠','또','연','엔','차','굿모닝','할','8','.',\
             '보다','새','주간','전망','추천','이슈','플러스','사','개월','때','..','임','속','’…','G','나','개','원','에서',\
             '하는','이유','달','→','권','?…','단독','간','배','30','K','저','와','하','/','1조','6','두','해야','분','형',\
             '황','공','&','앞두고','보','문','이번','익','X','1억',']"','치','산','를','오','해','S','우리','그','된','준','▶',\
             '건','재','반','라','10년','초','3분','월','신','p','급','조','줄','경','했다','구','진','이어','올','발','vs','강',\
             '국','9억','1년','난','판','면','"(','`…','살','아','인데','번','텍','팜','8월','Q','메','2년','점','하고','10월',\
             'D','비','됐다','채',"]'",'보니','손','확','종','동','팔','40','타','~','9월','2100','30%','땐','말','한다','요',\
             "',",'스','…`','단','16','길','12','3억','회','될까','호','용','2조','번째','일까','듯','최']

tokens_ko = [each_word for each_word in tokens_ko
           if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100)
# Out:
# [('상위', 2033),
#  ('순', 923),
#  ('하락', 724),
#  ('매수', 548),
#  ('외국인', 504),
#  ('기관', 494),
#  ('매', 375),
#  ('연속', 374),
#  ('승률', 334),
#  ('기준', 331),
#  ('주요', 306),
#  ('외국', 299),
#  ('수량', 252),
#  ('후', 209),
#  ('도일', 198),
#  ('공시', 175),
#  ('수일', 173),
#  ('뉴스', 111),
#  ('신고', 98),
#  ('비율', 98),
#  ('장마', 97),
#  ('신용', 96),
#  ('및', 90),
#  ('급등', 86),
#  ('상한', 84),
#  ('투자', 83),
#  ('일자', 76),
#  ('증권사', 69),
#  ('신규', 69),
#  ('의견', 65),
#  ('유지', 61),
#  ('株', 59),
#  ('뉴욕증시', 48),
#  ('금액', 47),
#  ('실적', 46),
#  ('재송', 34),
#  ('美', 33),
#  ('강세', 30),
#  ('종가', 29),
#  ('동시', 29),
#  ('호가', 29),
#  ('특이', 29),
#  ('테마', 26),
#  ('기업', 26),
#  ('공매도', 23),
#  ('상승', 23),
#  ('세계', 19),
#  ('나스닥', 19),
#  ('금리', 19),
#  ('SK', 19),
#  ('재개', 18),
#  ('오늘', 18),
#  ('발표', 18),
#  ('일정', 18),
#  ('↑', 18),
#  ('미국', 18),
#  ('스케줄', 17),
#  ('다우', 16),
#  ('개미', 16),
#  ('1분', 15),
#  ('변동', 15),
#  ('연결', 14),
#  ('삼성', 14),
#  ('테마주', 13),
#  ('최고', 13),
#  ('↓', 13),
#  ('시장', 13),
#  ('일제', 13),
#  ('주목', 13),
#  ('기대', 13),
#  ('+', 13),
#  ('주가', 13),
#  ('자산', 12),
#  ('배당', 12),
#  ('직전', 12),
#  ('30분', 12),
#  ('히', 12),
#  ('바이든', 12),
#  ('혼', 12),
#  ('사상', 12),
#  ('돌파', 12),
#  ('전자', 11),
#  ('우려', 11),
#  ('상장', 11),
#  ('ETF', 10),
#  ('국내', 10),
#  ('백신', 10),
#  ('영업', 10),
#  ('이익', 10),
#  ('예', 10),
#  ('상치', 10),
#  ('2021년', 10),
#  ('반도체', 9),
#  ('주식', 9),
#  ('평가', 9),
#  ('코로나', 9),
#  ('매도', 9),
#  ('국채', 9),
#  ('바이오', 9),
#  ('윤석열', 9)]

# %%
# 그래프에서 한글 폰트 깨지는 문제에 대한 대처(전역 글꼴 설정)

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family=font_name)

import graphviz
plt.figure(figsize=(15,6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data = ko.vocab().most_common(300)
data
# Out:
# [('상위', 2033),
#  ('순', 923),
#  ('하락', 724),
#  ('매수', 548),
#  ('외국인', 504),
#  ('기관', 494),
#  ('매', 375),
#  ('연속', 374),
#  ('승률', 334),
#  ('기준', 331),
#  ('주요', 306),
#  ('외국', 299),
#  ('수량', 252),
#  ('후', 209),
#  ('도일', 198),
#  ('공시', 175),
#  ('수일', 173),
#  ('뉴스', 111),
#  ('신고', 98),
#  ('비율', 98),
#  ('장마', 97),
#  ('신용', 96),
#  ('및', 90),
#  ('급등', 86),
#  ('상한', 84),
#  ('투자', 83),
#  ('일자', 76),
#  ('증권사', 69),
#  ('신규', 69),
#  ('의견', 65),
#  ('유지', 61),
#  ('株', 59),
#  ('뉴욕증시', 48),
#  ('금액', 47),
#  ('실적', 46),
#  ('재송', 34),
#  ('美', 33),
#  ('강세', 30),
#  ('종가', 29),
#  ('동시', 29),
#  ('호가', 29),
#  ('특이', 29),
#  ('테마', 26),
#  ('기업', 26),
#  ('공매도', 23),
#  ('상승', 23),
#  ('세계', 19),
#  ('나스닥', 19),
#  ('금리', 19),
#  ('SK', 19),
#  ('재개', 18),
#  ('오늘', 18),
#  ('발표', 18),
#  ('일정', 18),
#  ('↑', 18),
#  ('미국', 18),
#  ('스케줄', 17),
#  ('다우', 16),
#  ('개미', 16),
#  ('1분', 15),
#  ('변동', 15),
#  ('연결', 14),
#  ('삼성', 14),
#  ('테마주', 13),
#  ('최고', 13),
#  ('↓', 13),
#  ('시장', 13),
#  ('일제', 13),
#  ('주목', 13),
#  ('기대', 13),
#  ('+', 13),
#  ('주가', 13),
#  ('자산', 12),
#  ('배당', 12),
#  ('직전', 12),
#  ('30분', 12),
#  ('히', 12),
#  ('바이든', 12),
#  ('혼', 12),
#  ('사상', 12),
#  ('돌파', 12),
#  ('전자', 11),
#  ('우려', 11),
#  ('상장', 11),
#  ('ETF', 10),
#  ('국내', 10),
#  ('백신', 10),
#  ('영업', 10),
#  ('이익', 10),
#  ('예', 10),
#  ('상치', 10),
#  ('2021년', 10),
#  ('반도체', 9),
#  ('주식', 9),
#  ('평가', 9),
#  ('코로나', 9),
#  ('매도', 9),
#  ('국채', 9),
#  ('바이오', 9),
#  ('윤석열', 9),
#  ('등락', 9),
#  ('FOMC', 8),
#  ('한국', 8),
#  ('지수', 8),
#  ('200', 8),
#  ('거래', 8),
#  ('100', 8),
#  ('목표', 7),
#  ('18일', 7),
#  ('22일', 7),
#  ('24일', 7),
#  ('4일', 7),
#  ('연기금', 7),
#  ('미래에셋', 7),
#  ('유럽', 7),
#  ('사태', 7),
#  ('곳', 7),
#  ('바사', 7),
#  ('26일', 6),
#  ('시즌', 6),
#  ('韓', 6),
#  ('17일', 6),
#  ('급증', 6),
#  ('9일', 6),
#  ('급락', 6),
#  ('증권', 6),
#  ('최대', 6),
#  ('개선', 6),
#  ('동학', 6),
#  ('SKIET', 6),
#  ('개인', 6),
#  ('2021.04', 6),
#  ('TIGER', 6),
#  ('주말', 5),
#  ('랠리', 5),
#  ('상향', 5),
#  ('현대차', 5),
#  ('셀트리온', 5),
#  ('29일', 5),
#  ('너무', 5),
#  ('3000', 5),
#  ('3일', 5),
#  ('中', 5),
#  ('19일', 5),
#  ('간다', 5),
#  ('수혜', 5),
#  ('대감', 5),
#  ('5일', 5),
#  ('테슬라', 5),
#  ('차전지', 5),
#  ('경제', 5),
#  ('가능성', 5),
#  ('경신', 5),
#  ('반등', 5),
#  ('인프라', 5),
#  ('첫', 5),
#  ('낙폭', 5),
#  ('온다', 5),
#  ('5월', 5),
#  ('8일', 5),
#  ('테이퍼링', 4),
#  ('화', 4),
#  ('포인트', 4),
#  ('전기차', 4),
#  ('27일', 4),
#  ('변동성', 4),
#  ('28일', 4),
#  ('차량', 4),
#  ('4분', 4),
#  ('2021.02', 4),
#  ('쿠팡', 4),
#  ('혜주', 4),
#  ('10일', 4),
#  ('자금', 4),
#  ('영향', 4),
#  ('기아차', 4),
#  ('25일', 4),
#  ('2일', 4),
#  ('파월', 4),
#  ('인플레', 4),
#  ('국민연금', 4),
#  ('업종', 4),
#  ('테크', 4),
#  ('피', 4),
#  ('버스', 4),
#  ('회복', 4),
#  ('이후', 4),
#  ('종합', 4),
#  ('약세', 4),
#  ('경고', 4),
#  ('보합', 4),
#  ('‥', 4),
#  ('인상', 4),
#  ('2분', 4),
#  ('부양책', 4),
#  ('편입', 4),
#  ('되나', 4),
#  ('하며', 4),
#  ('장사', 4),
#  ('상폐', 4),
#  ('거래소', 4),
#  ('4000', 4),
#  ('12일', 4),
#  ('삼', 4),
#  ('차익', 4),
#  ('6일', 4),
#  ('카카오', 4),
#  ('4월', 4),
#  ('조선', 4),
#  ('코인', 4),
#  ('14일', 4),
#  ('19', 4),
#  ('할까', 4),
#  ('껑충', 4),
#  ('과대', 4),
#  ('팔고', 4),
#  ('외인', 4),
#  ('..."', 4),
#  ('지속', 4),
#  ('성장', 4),
#  ('전략', 4),
#  ('첫날', 4),
#  ('대비', 4),
#  ('13일', 4),
#  ('환율', 4),
#  ('올해', 4),
#  ('6000억원', 4),
#  ('가상', 4),
#  ('2021.05', 4),
#  ('15일', 3),
#  ('20일', 3),
#  ('LG', 3),
#  ('경계', 3),
#  ('잔고', 3),
#  ('위', 3),
#  ('붕괴', 3),
#  ('조정', 3),
#  ('오른', 3),
#  ('결산', 3),
#  ('하나', 3),
#  ('홍콩', 3),
#  ('들썩', 3),
#  ('사업', 3),
#  ('씨젠', 3),
#  ('속보', 3),
#  ('인플레이션', 3),
#  ('배터리', 3),
#  ('빅', 3),
#  ('담았다', 3),
#  ('16일', 3),
#  ('서학', 3),
#  ('사이언스', 3),
#  ('쇼크', 3),
#  ('누구', 3),
#  ('보유', 3),
#  ('기민', 3),
#  ('감주', 3),
#  ('봉쇄', 3),
#  ('위기', 3),
#  ('맞은', 3),
#  ('수익률', 3),
#  ('수에즈', 3),
#  ('운하', 3),
#  ('빌', 3),
#  ('조세', 3),
#  ('감사', 3),
#  ('주의보', 3),
#  ('이노베이션', 3),
#  ('개사', 3),
#  ('달러', 3),
#  ('유가', 3),
#  ('나무', 3),
#  ('추진', 3),
#  ('계획', 3),
#  ('P', 3),
#  ('포스코', 3),
#  ('검토', 3),
#  ('될', 3),
#  ('13조', 3),
#  ('입성', 3),
#  ('다시', 3),
#  ('지표', 3),
#  ('어디', 3),
#  ('사랑', 3),
#  ('비트코인', 3),
#  ('호조', 3),
#  ('은행', 3),
#  ('장세', 3),
#  ('3200', 3),
#  ('큰', 3),
#  ('아시아', 3),
#  ('내달', 3),
#  ('청약', 3),
#  ('러시아', 3),
#  ('긴축', 3),
#  ('대차', 3),
#  ('표적', 3),
#  ('전일', 3),
#  ('모', 3),
#  ('쓸어', 3)]

# %%
# 워드클라우드를 그려보자

wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                     relative_scaling=0.2,
                     background_color='white').generate_from_frequencies(dict(data))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# 돼지저금통 그림에 집어넣기

# %% [markdown]
# # 2. 감성분석 모델 만들기

# %%
news_df.head()
# Out:
#    Unnamed: 0                          뉴스제목  주가변동
# 0           0                    52주 신고가 종목     0
# 1           1   증시요약(9) - 기술적 분석 특징주 A(코스닥)     0
# 2           2  증시요약(10) - 기술적 분석 특징주 B(코스닥)     0
# 3           3         오후장 기술적 분석 특징주 A(코스닥)     0
# 4           4         오후장 기술적 분석 특징주 B(코스닥)     0

# %%
# 형태소 분석을 위한 함수

def tokenizer(text):
    okt = Okt()
    return okt.morphs(text)

# %%
def data_preprocessing():
    # 수집한 데이터 읽어오기
    # news_df = pd.read_excel()
    
    # 학습셋, 테스트셋 분리
    title_list = news_df['뉴스제목'].tolist()
    price_list = news_df['주가변동'].tolist()
    
    from sklearn.model_selection import train_test_split
    
    # 데이터의 80%는 학습셋, 20%는 테스트셋
    title_train, title_test, price_train, price_test = train_test_split(title_list, price_list, test_size=0.2, random_state=0)
    
    return title_train, title_test, price_train, price_test

# %%
def learning(x_train, y_train, x_test, y_test):
    # 전처리가 끝난 데이터를 단어 사전으로 만들고
    # 리뷰별로 나오는 단어를 파악해서 수치화 (벡터화)해서 학습
    # tfidf, 로지스틱 회귀 이용
    
    tfidf = TfidfVectorizer(lowercase=False, tokenizer=tokenizer)
    # 로지스틱
    logistic = LogisticRegression(C=2, penalty='l2', random_state=0)     # C의 숫자가 너무 크면 과적합 (기본 1), penalty로 과적합 방지
    
    pipe = Pipeline([('vect',tfidf),('clf',logistic)])
    
    # 학습
    pipe.fit(x_train, y_train)
    
    # 학습 정확도 측정
    y_pred = pipe.predict(x_test)
    print(accuracy_score(y_test, y_pred))
    
    # 학습한 모델을 저장
    with open('pipe.dat', 'wb') as fp:     # 쓰기, 바탕화면에 저장됨
        pickle.dump(pipe, fp)
        
    print('저장완료')     # 학습된 모델 저장 완료

# %%
def using():
    # 객체를 복원, 저장된 모델 불러오기
    with open('pipe.dat','rb') as fp:     # 읽기
        pipe = pickle.load(fp)
        
    while True :
        text = input('뉴스 타이틀을 입력해주세요 : ')     # 인풋
        
        str = [text]
        
        # 예측 정확도
        r1 = np.max(pipe.predict_proba(str)*100)     # 확률값을 구해서 *100..?
        
        # 예측 결과
        r2 = pipe.predict(str)[0]     # 긍정('1'), 부정('0')
        
        if r2 == '1':
            print('코스피지수는 상승할 것으로 예상됩니다.')
        else: 
            print('코스피지수는 하락할 것으로 예상됩니다.')
            
        print('정확도 : %.3f' % r1)
        print('------------------------------------------------')

# %%
# 학습 함수

def model_learning():   # 감성분석 모델 생성
    title_train, title_test, price_train, price_test = data_preprocessing()
    learning(title_train, price_train, title_test, price_test)
    
# 사용 함수

def model_using():   # 감성분석 모델 사용
    using()

# %%
model_learning()
# Out:
# 0.5020833333333333
# 저장완료

# %%
model_using()
